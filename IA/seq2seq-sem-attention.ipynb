# %%
import nltk
import numpy as np
import re
import shutil
import tensorflow as tf
import os
import unicodedata

from nltk.translate.bleu_score import sentence_bleu,SmoothingFunction

# %%
def preprocess_sentence(sent):
  sent = "".join([c for c in unicodedata.normalize('NFD',sent) if unicodedata.category(c) != 'Mn'])
  sent = re.sub(r"[^a-zA-Z!.?]+", r" ", sent)
  sent = re.sub(r"\s+", " ", sent)
  sent = sent.lower()
  return sent

# %%
def download_and_read():
  en_sents,fr_sents_in,fr_sents_out = [],[],[]
  local_file = '/content/drive/MyDrive/Colab Notebooks/livroDeDeepLearning/cap-8-recurrent-neural-networks/datasets/fra.txt'
  with open(local_file,'r') as fin:
    for i,line in enumerate(fin.readlines()):
      en_sent,fr_sent = line.strip().split('\t')[:2]
      en_sent = preprocess_sentence(en_sent)
      fr_sent = preprocess_sentence(fr_sent)
      
      fr_sent_in = [w for w in ("BOS "+fr_sent).split()]
      fr_sent_out = [w for w in (fr_sent + " EOS").split()]
      en_sent = [w for w in en_sent.split()]

      en_sents.append(en_sent)
      fr_sents_in.append(fr_sent_in)
      fr_sents_out.append(fr_sent_out)

      if i > 30000:
        break

  return en_sents,fr_sents_in, fr_sents_out

# %%
sents_en, sents_fr_in, sents_fr_out = download_and_read()

# %%
tokenizer_en = tf.keras.preprocessing.text.Tokenizer(filters='',lower=False)
tokenizer_en.fit_on_texts(sents_en)
data_en = tokenizer_en.texts_to_sequences(sents_en)
data_en = tf.keras.preprocessing.sequence.pad_sequences(data_en,padding='post')

# %%
tokenizer_fr = tf.keras.preprocessing.text.Tokenizer(filters='',lower=False)
tokenizer_fr.fit_on_texts(sents_fr_in)
tokenizer_fr.fit_on_texts(sents_fr_out)

data_fr_in = tokenizer_fr.texts_to_sequences(sents_fr_in)
data_fr_out = tokenizer_fr.texts_to_sequences(sents_fr_out)

data_fr_in = tf.keras.preprocessing.sequence.pad_sequences(data_fr_in,padding='post')
data_fr_out = tf.keras.preprocessing.sequence.pad_sequences(data_fr_out,padding='post')

# %%
vocab_size_en = len(tokenizer_en.word_index)
vocab_size_fr = len(tokenizer_fr.word_index)

word2idx_en = tokenizer_en.word_index
idx2word_en = {i:k for k,i in word2idx_en.items()}

word2idx_fr = tokenizer_fr.word_index
idx2word_fr = {i:k for k,i in word2idx_fr.items()}

print("vocab size (en): {:d}, vocab size (fr): {:d}".format(vocab_size_en, vocab_size_fr))
# Out:
# vocab size (en): 6258, vocab size (fr): 9835

# %%
NUM_SENT_PAIRS = len(sents_en)
batch_size = 64
dataset = tf.data.Dataset.from_tensor_slices((data_en,data_fr_in,data_fr_out))
dataset = dataset.shuffle(10000)
test_size = NUM_SENT_PAIRS // 4
test_dataset = dataset.take(test_size).batch(batch_size,drop_remainder=True)
train_dataset = dataset.skip(test_size).batch(batch_size,drop_remainder=True)

# %%
class Encoder(tf.keras.Model):

  def __init__(self,vocab_size,num_timesteps,embedding_dim,encoder_dim,**kwargs):
    super(Encoder,self).__init__(**kwargs)

    self.encoder_dim = encoder_dim

    self.embedding = tf.keras.layers.Embedding(vocab_size,embedding_dim, input_length= num_timesteps)

    self.rnn = tf.keras.layers.GRU(encoder_dim,return_sequences=False,return_state=True)
  
  def call(self,x,state):
    x = self.embedding(x)
    x, state = self.rnn(x,initial_state=state)
    return x,state
  
  def init_state(self,batch_size):
    return tf.zeros((batch_size,self.encoder_dim))

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, num_timesteps, decoder_dim, **kwargs):
    super(Decoder,self).__init__(**kwargs)

    self.decoder_dim = decoder_dim
    self.embedding = tf.keras.layers.Embedding(vocab_size,embedding_dim,input_length=num_timesteps)

    self.rnn = tf.keras.layers.GRU(decoder_dim,return_sequences=True,return_state=True)
    self.dense = tf.keras.layers.Dense(vocab_size)

  def call(self,x,state):
    x = self.embedding(x)
    x,state = self.rnn(x,state)
    x = self.dense(x)
    return x,state

# %%
embedding_dim = 256
encoder_dim, decoder_dim = 1024,1024
maxlen_en = data_en.shape[1]
maxlen_fr = data_fr_out.shape[1]

encoder = Encoder(vocab_size_en+1,maxlen_en,embedding_dim,encoder_dim)
decoder = Decoder(vocab_size_fr+1,embedding_dim,maxlen_fr,decoder_dim)

# %%
for encoder_in, decoder_in, decoder_out in train_dataset:
  encoder_state = encoder.init_state(batch_size)
  encoder_out, encoder_state = encoder(encoder_in, encoder_state)
  decoder_state = encoder_state
  decoder_pred, decoder_state = decoder(decoder_in, decoder_state)
  break
print("encoder input :", encoder_in.shape)
print("encoder output :", encoder_out.shape, "state:",encoder_state.shape)
print("decoder output (logits):", decoder_pred.shape, "state:",
decoder_state.shape)
print("decoder output (labels):", decoder_out.shape)
# Out:
# encoder input : (64, 7)
# encoder output : (64, 1024) state: (64, 1024)
# decoder output (logits): (64, 15, 9836) state: (64, 1024)
# decoder output (labels): (64, 15)

# %%
def loss_fn(ytrue,ypred):
  scce = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
  mask = tf.math.logical_not(tf.math.equal(ytrue,0))
  mask = tf.cast(mask, dtype=tf.int64)
  loss = scce(ytrue,ypred,sample_weight=mask)
  return loss

# %%
@tf.function
def train_step(encoder_in, decoder_in, decoder_out, encoder_state):
  with tf.GradientTape() as tape:
    encoder_out, encoder_state = encoder(encoder_in, encoder_state)
    decoder_state = encoder_state
    decoder_pred, decoder_state = decoder(decoder_in,decoder_state)
    loss = loss_fn(decoder_out,decoder_pred)
  variables = (encoder.trainable_variables + decoder.trainable_variables)
  gradients = tape.gradient(loss,variables)
  
  optimizer.apply_gradients(zip(gradients,variables))

  return loss

# %%
def predict(encoder, decoder, sents_en,
            data_en, sents_fr_out, word2idx_fr, idx2word_fr):
  random_id = np.random.choice(len(sents_en))
  encoder_in = tf.expand_dims(data_en[random_id],axis=0)
  decoder_out = tf.expand_dims(sents_fr_out[random_id],axis=0)

  encoder_state = encoder.init_state(1)
  encoder_out, encoder_state = encoder(encoder_in,encoder_state)
  decoder_in = tf.expand_dims(tf.constant([word2idx_fr['BOS']]),axis=0)
  decoder_state = encoder_state
  pred_sent_fr = []
  while True:
    decoder_pred, decoder_state = decoder(decoder_in,decoder_state)
    decoder_pred = tf.argmax(decoder_pred,axis=-1)
    pred_word = idx2word_fr[decoder_pred.numpy()[0][0]]
    pred_sent_fr.append(pred_word)
    if pred_word == 'EOS':
      break
    decoder_in = decoder_pred
  print('inglês: '," ".join(sents_en[random_id]))
  print('true: '," ".join(sents_fr_out[random_id]))
  print("predicted: ", " ".join(pred_sent_fr))

# %%
optimizer = tf.keras.optimizers.Adam()
checkpoint_prefix = os.path.join(".", "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,encoder=encoder,decoder=decoder)

# %%
num_epochs = 250
eval_scores = []

for e in range(num_epochs):
  encoder_state = encoder.init_state(batch_size)

  for batch,data in enumerate(train_dataset):
    encoder_in, decoder_in, decoder_out = data
    loss = train_step(encoder_in,decoder_in,decoder_out,encoder_state)
  
  print("Epoch: {}, Loss: {:.4f}".format(e + 1, loss.numpy()))

  predict(encoder, decoder, sents_en, data_en, sents_fr_out, word2idx_fr, idx2word_fr)
# Out:
# Epoch: 1, Loss: 1.3098
# inglês:  i paid my taxes.
# true:  j ai paye mes impots. EOS
# predicted:  j aime les bandes EOS
# Epoch: 2, Loss: 1.0246
# inglês:  i haven t started.
# true:  je n ai pas commence. EOS
# predicted:  je ne suis pas si fatigue. EOS
# Epoch: 3, Loss: 0.8095
# inglês:  i built a shelter.
# true:  j ai construit un abri. EOS
# predicted:  j ai eu un arbre. EOS
# Epoch: 4, Loss: 0.6207
# inglês:  my name is tom.
# true:  mon nom est tom. EOS
# predicted:  j ai les mains froides. EOS
# Epoch: 5, Loss: 0.4270
# inglês:  is that a wig?
# true:  est ce une perruque ? EOS
# predicted:  est ce une urgence ? EOS
# Epoch: 6, Loss: 0.3754
# inglês:  tom seems worried.
# true:  tom semble inquiet. EOS
# predicted:  tom a l air d etre cote. EOS
# Epoch: 7, Loss: 0.2970
# inglês:  was anybody hurt?
# true:  qui que ce soit a t il ete blesse ? EOS
# predicted:  qui a ete tue ? EOS
# Epoch: 8, Loss: 0.2752
# inglês:  what woke you up?
# true:  qu est ce qui vous a reveillees ? EOS
# predicted:  qu est ce qui vous a reveille ? EOS
# Epoch: 9, Loss: 0.2239
# inglês:  you won t be shot.
# true:  on ne te tirera pas dessus. EOS
# predicted:  vous ne serez pas fusilles. EOS
# Epoch: 10, Loss: 0.1994
# inglês:  this is very good.
# true:  c est tres bon. EOS
# predicted:  c est tres bon. EOS
# Epoch: 11, Loss: 0.1974
# inglês:  tom drinks coffee.
# true:  tom boit du cafe. EOS
# predicted:  tom boit du cafe. EOS
# Epoch: 12, Loss: 0.1655
# inglês:  don t attack me.
# true:  ne m attaquez pas ! EOS
# predicted:  ne m interrompez pas ! EOS
# Epoch: 13, Loss: 0.1687
# inglês:  she is not wrong.
# true:  elle n a pas tort. EOS
# predicted:  elle n a pas tort. EOS
# Epoch: 14, Loss: 0.1253
# inglês:  i m not your maid.
# true:  je ne suis pas votre bonne. EOS
# predicted:  je ne suis pas votre servante. EOS
# Epoch: 15, Loss: 0.1380
# inglês:  don t wait up.
# true:  ne veillez pas. EOS
# predicted:  ne veillez pas. EOS
# Epoch: 16, Loss: 0.1723
# inglês:  i hate this job.
# true:  moi je deteste ce boulot. EOS
# predicted:  je deteste ce boulot. EOS
# Epoch: 17, Loss: 0.1547
# inglês:  you re annoying.
# true:  tu m ennuies. EOS
# predicted:  tu es chiante. EOS
# Epoch: 18, Loss: 0.1385
# inglês:  we didn t kiss.
# true:  on ne s est pas embrasses. EOS
# predicted:  nous ne disposons pas pas de chichis. EOS
# Epoch: 19, Loss: 0.1712
# inglês:  i did have fun.
# true:  je me suis amusee. EOS
# predicted:  je me suis amusee. EOS
# Epoch: 20, Loss: 0.1320
# inglês:  this is in french.
# true:  c est en francais. EOS
# predicted:  c est en francais. EOS
# Epoch: 21, Loss: 0.1369
# inglês:  did they say how?
# true:  ont elles dit comment ? EOS
# predicted:  ont ils dit comment ? EOS
# Epoch: 22, Loss: 0.1473
# inglês:  i was hammered.
# true:  j etais dechire. EOS
# predicted:  j etais dechire. EOS
# Epoch: 23, Loss: 0.1708
# inglês:  i m greedy.
# true:  je suis cupide. EOS
# predicted:  je suis gourmande. EOS
# Epoch: 24, Loss: 0.1193
# inglês:  tom has my book.
# true:  tom a mon livre. EOS
# predicted:  tom a mon livre. EOS
# Epoch: 25, Loss: 0.1284
# inglês:  we re in love.
# true:  nous sommes amoureux. EOS
# predicted:  nous sommes amoureuses. EOS
# Epoch: 26, Loss: 0.1348
# inglês:  i ll decide.
# true:  j en deciderai. EOS
# predicted:  j en deciderai. EOS
# Epoch: 27, Loss: 0.1224
# inglês:  i was excited.
# true:  j etais excitee. EOS
# predicted:  j etais excite. EOS
# Epoch: 28, Loss: 0.1145
# inglês:  burn it.
# true:  brulez le. EOS
# predicted:  brulez le. EOS
# Epoch: 29, Loss: 0.1340
# inglês:  here she is!
# true:  la voila ! EOS
# predicted:  la voila ! EOS
# Epoch: 30, Loss: 0.1237
# inglês:  i had to stop.
# true:  il fallait que j arrete. EOS
# predicted:  il m a fallu arreter. EOS
# Epoch: 31, Loss: 0.1321
# inglês:  she isn t running.
# true:  elle ne court pas. EOS
# predicted:  elle ne court pas. EOS
# Epoch: 32, Loss: 0.1296
# inglês:  i was curious.
# true:  j etais curieuse. EOS
# predicted:  j etais curieuse. EOS
# Epoch: 33, Loss: 0.1418
# inglês:  they re working.
# true:  elles travaillent. EOS
# predicted:  ils travaillent. EOS
# Epoch: 34, Loss: 0.1068
# inglês:  this is hilarious.
# true:  c est a se plier de rire. EOS
# predicted:  c est tordant. EOS
# Epoch: 35, Loss: 0.1139
# inglês:  get out of my seat.
# true:  libere mon siege ! EOS
# predicted:  liberez mon siege ! EOS
# Epoch: 36, Loss: 0.1599
# inglês:  check these out.
# true:  regarde celles ci ! EOS
# predicted:  regarde ceux ci ! EOS
# Epoch: 37, Loss: 0.0818
# inglês:  i didn t go.
# true:  je n y suis pas alle. EOS
# predicted:  je n y suis pas allee. EOS
# Epoch: 38, Loss: 0.0784
# inglês:  i m very fat.
# true:  je suis tres gras. EOS
# predicted:  je suis tres gras. EOS
# Epoch: 39, Loss: 0.0865
# inglês:  no one trusts tom.
# true:  personne ne fait confiance a tom. EOS
# predicted:  personne ne fait confiance a tom. EOS
# Epoch: 40, Loss: 0.1062
# inglês:  bring wine.
# true:  apportez du vin. EOS
# predicted:  apporte du vin. EOS
# Epoch: 41, Loss: 0.1037
# inglês:  be prepared.
# true:  tiens toi pret ! EOS
# predicted:  soyez preparee ! EOS
# Epoch: 42, Loss: 0.1080
# inglês:  i made a promise.
# true:  j ai fait une promesse. EOS
# predicted:  j ai fait une promesse. EOS
# Epoch: 43, Loss: 0.0973
# inglês:  wash the dishes.
# true:  lavez la vaisselle ! EOS
# predicted:  lavez la vaisselle ! EOS
# Epoch: 44, Loss: 0.1126
# inglês:  i tried to escape.
# true:  j ai essaye de m echapper. EOS
# predicted:  j ai essaye de m echapper. EOS
# Epoch: 45, Loss: 0.1123
# inglês:  once is not enough.
# true:  une fois ne suffit pas. EOS
# predicted:  une fois ne suffit pas. EOS
# Epoch: 46, Loss: 0.1193
# inglês:  the enemy is weak.
# true:  l ennemi est faible. EOS
# predicted:  l ennemi est faible. EOS
# Epoch: 47, Loss: 0.0924
# inglês:  wake tom up.
# true:  reveille tom ! EOS
# predicted:  reveille tom ! EOS
# Epoch: 48, Loss: 0.0919
# inglês:  i ate on the bus.
# true:  j ai mange dans le bus. EOS
# predicted:  j ai mange dans le bus. EOS
# Epoch: 49, Loss: 0.1187
# inglês:  it s embarrassing.
# true:  c est embarrassant. EOS
# predicted:  c est embarrassant. EOS
# Epoch: 50, Loss: 0.0786
# inglês:  give me five days.
# true:  donnez moi cinq jours. EOS
# predicted:  donnez moi cinq jours. EOS
# Epoch: 51, Loss: 0.1145
# inglês:  tom runs fast.
# true:  tom court vite. EOS
# predicted:  tom court vite. EOS
# Epoch: 52, Loss: 0.0994
# inglês:  memorize this.
# true:  rappelez vous ceci. EOS
# predicted:  rappelez vous ceci. EOS
# Epoch: 53, Loss: 0.0779
# inglês:  this is amazing.
# true:  c est incroyable. EOS
# predicted:  c est incroyable. EOS
# Epoch: 54, Loss: 0.0827
# inglês:  we need to eat.
# true:  il nous faut manger. EOS
# predicted:  il nous faut manger. EOS
# Epoch: 55, Loss: 0.1063
# inglês:  we re dedicated.
# true:  nous sommes devouees. EOS
# predicted:  nous sommes devoues. EOS
# Epoch: 56, Loss: 0.0919
# inglês:  i want that bag.
# true:  je veux ce sac. EOS
# predicted:  je veux ce sac. EOS
# Epoch: 57, Loss: 0.1112
# inglês:  i have no choice.
# true:  je n ai pas le choix. EOS
# predicted:  je n ai pas le choix. EOS
# Epoch: 58, Loss: 0.0840
# inglês:  she left me a note.
# true:  elle me laissa une note. EOS
# predicted:  elle me laissa une note. EOS
# Epoch: 59, Loss: 0.0943
# inglês:  be nice to others.
# true:  sois gentil avec les autres ! EOS
# predicted:  sois gentil avec les autres ! EOS
# Epoch: 60, Loss: 0.0862
# inglês:  i was humiliated.
# true:  on m a humilie. EOS
# predicted:  on m a humilie. EOS
# Epoch: 61, Loss: 0.0898
# inglês:  have a nice time.
# true:  amusez vous bien ! EOS
# predicted:  passe du bon temps ! EOS
# Epoch: 62, Loss: 0.0965
# inglês:  we arrived first.
# true:  nous arrivames les premiers. EOS
# predicted:  nous arrivames les premiers. EOS
# Epoch: 63, Loss: 0.0705
# inglês:  my horse is black.
# true:  mon cheval est noir. EOS
# predicted:  mon cheval est noir. EOS
# Epoch: 64, Loss: 0.1107
# inglês:  i go to school.
# true:  je vais a l ecole. EOS
# predicted:  je me suis a l ecole. EOS
# Epoch: 65, Loss: 0.1086
# inglês:  they re mine.
# true:  ils sont a moi. EOS
# predicted:  ce sont les miens. EOS
# Epoch: 66, Loss: 0.0716
# inglês:  why are you alone?
# true:  pourquoi etes vous seul ? EOS
# predicted:  pourquoi etes vous seul ? EOS
# Epoch: 67, Loss: 0.0721
# inglês:  i lost your number.
# true:  j ai perdu ton numero. EOS
# predicted:  j ai perdu votre numero. EOS
# Epoch: 68, Loss: 0.1228
# inglês:  tom caught mary.
# true:  tom a surpris marie. EOS
# predicted:  tom a surpris marie. EOS
# Epoch: 69, Loss: 0.0968
# inglês:  you re charming.
# true:  vous etes charmantes. EOS
# predicted:  tu es charmant. EOS
# Epoch: 70, Loss: 0.0836
# inglês:  i got lost.
# true:  je me suis perdu. EOS
# predicted:  je me suis perdu. EOS
# Epoch: 71, Loss: 0.0765
# inglês:  i grow tomatoes.
# true:  je cultive des tomates. EOS
# predicted:  je cultive des tomates. EOS
# Epoch: 72, Loss: 0.0784
# inglês:  no one likes it.
# true:  personne n aime ca. EOS
# predicted:  personne n aime ca. EOS
# Epoch: 73, Loss: 0.1008
# inglês:  she fainted.
# true:  elle est tombee dans les pommes. EOS
# predicted:  elle est tombee dans les pommes. EOS
# Epoch: 74, Loss: 0.1071
# inglês:  let s review.
# true:  passons en revue. EOS
# predicted:  faisons le point. EOS
# Epoch: 75, Loss: 0.0736
# inglês:  let s move.
# true:  on se tire. EOS
# predicted:  on se casse. EOS
# Epoch: 76, Loss: 0.0876
# inglês:  did i wake you up?
# true:  vous ai je reveilles ? EOS
# predicted:  t ai je reveillee ? EOS
# Epoch: 77, Loss: 0.0861
# inglês:  i signed the form.
# true:  j ai signe le formulaire. EOS
# predicted:  j ai signe le formulaire. EOS
# Epoch: 78, Loss: 0.1205
# inglês:  tom has red hair.
# true:  tom a les cheveux rouges. EOS
# predicted:  tom a les cheveux roux. EOS
# Epoch: 79, Loss: 0.0956
# inglês:  throw me the ball.
# true:  jetez moi la balle. EOS
# predicted:  lancez moi la balle. EOS
# Epoch: 80, Loss: 0.0892
# inglês:  control yourself.
# true:  maitrisez vous. EOS
# predicted:  controle toi. EOS
# Epoch: 81, Loss: 0.0840
# inglês:  are drinks free?
# true:  les boissons sont elles gratuites ? EOS
# predicted:  est ce que les boissons sont gratuites ? EOS
# Epoch: 82, Loss: 0.0751
# inglês:  the knife is dull.
# true:  le couteau est emousse. EOS
# predicted:  le couteau est emousse. EOS
# Epoch: 83, Loss: 0.1061
# inglês:  they are very big.
# true:  ils sont tres grands. EOS
# predicted:  elles sont tres massives. EOS
# Epoch: 84, Loss: 0.0787
# inglês:  i have to know why.
# true:  je dois savoir pourquoi. EOS
# predicted:  je dois savoir pourquoi. EOS
# Epoch: 85, Loss: 0.0544
# inglês:  write in ink.
# true:  ecrivez a l encre. EOS
# predicted:  ecrivez a l encre. EOS
# Epoch: 86, Loss: 0.0989
# inglês:  get going.
# true:  deplacez vous. EOS
# predicted:  allez y. EOS
# Epoch: 87, Loss: 0.0766
# inglês:  get changed.
# true:  changez vous. EOS
# predicted:  changez vous. EOS
# Epoch: 88, Loss: 0.0816
# inglês:  i want my money.
# true:  je veux mon argent. EOS
# predicted:  je veux mon argent. EOS
# Epoch: 89, Loss: 0.0864
# inglês:  that s disturbing.
# true:  c est derangeant. EOS
# predicted:  c est derangeant. EOS
# Epoch: 90, Loss: 0.0851
# inglês:  this is too big.
# true:  c est tres gros. EOS
# predicted:  c est tres gros. EOS
# Epoch: 91, Loss: 0.0681
# inglês:  this was my idea.
# true:  c etait mon idee. EOS
# predicted:  c etait mon idee. EOS
# Epoch: 92, Loss: 0.0761
# inglês:  it s worth a shot.
# true:  ca vaut le coup d essayer. EOS
# predicted:  ca vaut le coup d essayer. EOS
# Epoch: 93, Loss: 0.0840
# inglês:  i m your friend.
# true:  je suis ton amie. EOS
# predicted:  je suis votre amie. EOS
# Epoch: 94, Loss: 0.0751
# inglês:  tom has remarried.
# true:  tom s est remarie. EOS
# predicted:  tom s est remarie. EOS
# Epoch: 95, Loss: 0.0823
# inglês:  how can i pay?
# true:  comment puis je payer? EOS
# predicted:  comment puis je payer? EOS
# Epoch: 96, Loss: 0.0662
# inglês:  i believe you.
# true:  je te crois. EOS
# predicted:  je te crois. EOS
# Epoch: 97, Loss: 0.0772
# inglês:  yes. that s right.
# true:  oui. c est exact. EOS
# predicted:  nous avons presque raison. EOS
# Epoch: 98, Loss: 0.0810
# inglês:  they re brave.
# true:  ils n ont pas froid aux yeux. EOS
# predicted:  ils sont courageux. EOS
# Epoch: 99, Loss: 0.0825
# inglês:  hug me.
# true:  serrez moi dans vos bras ! EOS
# predicted:  serre moi dans tes bras ! EOS
# Epoch: 100, Loss: 0.0897
# inglês:  she adores him.
# true:  elle l adore. EOS
# predicted:  elle l adore. EOS
# Epoch: 101, Loss: 0.0911
# inglês:  what is your name?
# true:  comment est ce que tu t appelles ? EOS
# predicted:  quel est votre nom ? EOS
# Epoch: 102, Loss: 0.0781
# inglês:  i am just a nobody.
# true:  je suis juste un monsieur tout le monde. EOS
# predicted:  je suis juste un monsieur tout le monde. EOS
# Epoch: 103, Loss: 0.0982
# inglês:  you had better go.
# true:  tu ferais mieux de partir. EOS
# predicted:  tu ferais mieux de partir. EOS
# Epoch: 104, Loss: 0.0765
# inglês:  i was kidnapped.
# true:  j ai ete kidnappee. EOS
# predicted:  j ai ete kidnappee. EOS
# Epoch: 105, Loss: 0.0751
# inglês:  don t shoot!
# true:  ne tire pas ! EOS
# predicted:  ne tirez pas ! EOS
# Epoch: 106, Loss: 0.0909
# inglês:  we were bored.
# true:  nous nous ennuyions. EOS
# predicted:  nous nous ennuyions. EOS
# Epoch: 107, Loss: 0.0898
# inglês:  what if he fails?
# true:  que se passe t il s il echoue ? EOS
# predicted:  que se passe t il s il echoue ? EOS
# Epoch: 108, Loss: 0.0608
# inglês:  it s too cold.
# true:  il fait trop froid. EOS
# predicted:  il fait trop froid. EOS
# Epoch: 109, Loss: 0.0632
# inglês:  i m serious.
# true:  je suis serieux. EOS
# predicted:  je suis serieux. EOS
# Epoch: 110, Loss: 0.0685
# inglês:  does he live here?
# true:  vit il ici ? EOS
# predicted:  est ce qu il habite ici ? EOS
# Epoch: 111, Loss: 0.0808
# inglês:  try to find it.
# true:  tentez de le trouver. EOS
# predicted:  essaie de le trouver. EOS
# Epoch: 112, Loss: 0.0615
# inglês:  they re talking.
# true:  ils parlent. EOS
# predicted:  ils parlent. EOS
# Epoch: 113, Loss: 0.0784
# inglês:  did i mention that?
# true:  l ai je mentionne ? EOS
# predicted:  en ai je fait mention ? EOS
# Epoch: 114, Loss: 0.0758
# inglês:  it s just money.
# true:  il ne s agit que d argent. EOS
# predicted:  il ne s agit que d argent. EOS
# Epoch: 115, Loss: 0.0862
# inglês:  this is reality.
# true:  c est la realite. EOS
# predicted:  c est la realite. EOS
# Epoch: 116, Loss: 0.0791
# inglês:  she tried.
# true:  elle a essaye. EOS
# predicted:  elle a essaye. EOS
# Epoch: 117, Loss: 0.0816
# inglês:  i know.
# true:  je sais. EOS
# predicted:  je sais. EOS
# Epoch: 118, Loss: 0.0803
# inglês:  is there a point?
# true:  a quoi ca sert ? EOS
# predicted:  a quoi cela sert il ? EOS
# Epoch: 119, Loss: 0.0766
# inglês:  how s your mother?
# true:  comment va ta mere ? EOS
# predicted:  comment va ta mere ? EOS
# Epoch: 120, Loss: 0.0589
# inglês:  it s acceptable.
# true:  c est acceptable. EOS
# predicted:  c est acceptable. EOS
# Epoch: 121, Loss: 0.0776
# inglês:  i baked it for you.
# true:  je l ai cuit pour toi. EOS
# predicted:  je le cuisis pour toi. EOS
# Epoch: 122, Loss: 0.0829
# inglês:  i want to see it.
# true:  je veux le voir. EOS
# predicted:  je veux le voir. EOS
# Epoch: 123, Loss: 0.0633
# inglês:  did you vote?
# true:  as tu vote ? EOS
# predicted:  as tu vote ? EOS
# Epoch: 124, Loss: 0.0897
# inglês:  i can t excuse her.
# true:  je ne peux pas l excuser. EOS
# predicted:  je ne peux pas l excuser. EOS
# Epoch: 125, Loss: 0.0860
# inglês:  it s all mine.
# true:  tout est a moi. EOS
# predicted:  tout est a moi. EOS
# Epoch: 126, Loss: 0.0769
# inglês:  my wife s pregnant.
# true:  ma femme est enceinte. EOS
# predicted:  ma femme est enceinte. EOS
# Epoch: 127, Loss: 0.0704
# inglês:  tom is shocked.
# true:  tom est sous le choc. EOS
# predicted:  tom est choque. EOS
# Epoch: 128, Loss: 0.0730
# inglês:  it was disastrous.
# true:  ce fut desastreux. EOS
# predicted:  ce fut desastreux. EOS
# Epoch: 129, Loss: 0.0588
# inglês:  i m all set.
# true:  je suis tout a fait prete. EOS
# predicted:  je suis tout a fait prete. EOS
# Epoch: 130, Loss: 0.0759
# inglês:  they re laughing.
# true:  ils rient. EOS
# predicted:  elles rient. EOS
# Epoch: 131, Loss: 0.0668
# inglês:  i m just a teacher.
# true:  je ne suis qu un enseignant. EOS
# predicted:  je ne suis qu un enseignant. EOS
# Epoch: 132, Loss: 0.0714
# inglês:  do you work here?
# true:  est ce que vous travaillez ici ? EOS
# predicted:  travaillez vous ? EOS
# Epoch: 133, Loss: 0.0851
# inglês:  i forbid that.
# true:  j interdis cela. EOS
# predicted:  j interdis cela. EOS
# Epoch: 134, Loss: 0.0732
# inglês:  i worked hard.
# true:  je travaillais dur. EOS
# predicted:  je travaillais dur. EOS
# Epoch: 135, Loss: 0.0713
# inglês:  can we come?
# true:  pouvons nous venir ? EOS
# predicted:  pouvons nous venir ? EOS
# Epoch: 136, Loss: 0.0598
# inglês:  he has another son.
# true:  il a un autre fils. EOS
# predicted:  il a un autre fils. EOS
# Epoch: 137, Loss: 0.0610
# inglês:  you are deranged.
# true:  tu es derange. EOS
# predicted:  tu es derange. EOS
